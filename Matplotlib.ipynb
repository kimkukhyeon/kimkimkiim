# %% [markdown]
# <a href="https://colab.research.google.com/github/kimkukhyeon/kimkimkiim/blob/master/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

data = [10, 20, 30]
x = [1, 2, 3]
plt.plot(x, data)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(['kim', 'lee', 'kang'], [85, 88, 90])

plt.title('English Score of three steudents')
plt.xlabel('Student Name')
plt.ylabel('Score')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='Malgun Gothic')

font1 = {'size':18, 'color':'green'}

xdata = ['안지영', '홍지수', '황예린']
ydata = [90, 85, 88]
plt.plot(xdata, ydata)

plt.title('세명 학생의 국어 성적', fontdict=font1)
plt.xlabel('이름')
plt.ylabel('성적')

plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 0s (22.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

xdata = ['안지영', '홍지수', '황예린']
ydata = [90, 85, 88]
plt.plot(xdata, ydata)

plt.title('세명 학생의 국어 성적', fontdict=font1)
plt.xlabel('이름')
plt.ylabel('성적')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

xdata = ['안지영', '홍지수', '황예린']
ydata1 = [90, 85, 88]
ydata2 = [83, 88, 91]

plt.plot(xdata, ydata1, label = '국어')
plt.plot(xdata, ydata2, label = '영어')
plt.legend(loc = 'upper center')


plt.title('세명 학생의 국어, 영어 성적', fontdict=font1)
plt.xlabel('이름')
plt.ylabel('성적')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

xdata = ['안지영', '홍지수', '황예린']
ydata1 = [90, 85, 88]
ydata2 = [83, 88, 91]
ydata3 = [85, 97, 78]
ydata4 = [92, 88, 82]

plt.plot(xdata, ydata1, label = '국어', color = 'red', linestyle = '-', marker = 'o')
plt.plot(xdata, ydata2, label = '영어', color = '#00ffff', linestyle = '--', marker = 'x')
plt.plot(xdata, ydata3, label = '수학', color = 'magenta', linestyle = '-.', marker = 's')
plt.plot(xdata, ydata4, label = '과학', color = '#444444', linestyle = ':', marker = 'd')

plt.legend(loc = 'best')
plt.title('세명 학생의 국어, 영어, 수학, 과학 성적', fontdict=font1)
plt.xlabel('이름')
plt.ylabel('성적')

plt.show()

# %%
import matplotlib.pyplot as plt

xdata = list(range(30))
ydata =[]

for x in xdata:
  y = 2 * x
  ydata.append(y)

plt.plot(xdata, ydata, label = 'y=2x')
plt.xlim(0, 35)
plt.ylim(0, 70)
plt.xticks(list(range(0, 35, 2)))
plt.yticks(list(range(0, 70, 5)))

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

xdata = list(range(30))
ydata =[]

for x in xdata:
  y = 2 * x
  ydata.append(y)

plt.plot(xdata, ydata)
plt.xlim(0, 35)
plt.ylim(0, 70)
plt.xticks(list(range(0, 35, 2)))
plt.yticks(list(range(0, 70, 5)))

plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

x = ['영희', '철수', '재호']
y = [3, 1, 5]
plt.bar(x, y)
plt.title('연간 영화관람 회수', fontdict=font1)
plt.xlabel('이름')
plt.ylabel('회수')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

x = ['월', '화', '수', '목', '금', '토', '일']
y = [6.5, 5.7, 5.5, 6.7, 6.3, 7.5, 8.3]
plt.title('연간 요일별 평균 수면시간', fontdict=font1)
plt.scatter(x, y)
plt.xlabel('요일')
plt.ylabel('수면시간')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

pets = ['개', '고양이', '기타', '기르지않음']
portion = [18, 3.4, 3.1, 75.5]
plt.title('총 가구 대비 반려동물 기르는 비율(2018)', fontdict=font1)
plt.pie(portion, explode=(0, 0.1, 0, 0), labels=pets, autopct='%1.1f%%', shadow=True, startangle=90)
plt.show()

# %%
import matplotlib.pyplot as plt

date = list(range(1, 11))
min_temp = [7.3, 3.5, 7.2, 4.5, 3.5, 8.3, 7.7, 6.4, 9.3, 6.3]
max_temp = [15, 16.3, 15.2, 17.5, 18.3, 20.0, 18.8, 17.5, 14.2, 15.3]

plt.plot(date, min_temp, label='Min Temperature', color='red', linestyle='-', marker='o')
plt.plot(date, max_temp, label='Max Temperature', color='blue', linestyle='-.', marker='x')

plt.legend(loc='best')
plt.xlabel('date')
plt.ylabel('temperature')
plt.title('Min and Max temperature of ten days')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

xdata = ['안지영', '홍지수', '황예린']
ydata1 = [90, 85, 88]
ydata2 = [83, 88, 91]
ydata3 = [85, 97, 78]
ydata4 = [92, 88, 82]

plt.plot(xdata, ydata1, label = '국어', color = 'red', linestyle = '-', marker = 'o')
plt.plot(xdata, ydata2, label = '영어', color = 'green', linestyle = '--', marker = 'x')
plt.plot(xdata, ydata3, label = '수학', color = 'blue', linestyle = '-.', marker = 's')
plt.plot(xdata, ydata4, label = '과학', color = 'cyan', linestyle = ':', marker = 'd')

plt.ylim(0, 100)
plt.legend(loc = 'best')
plt.title('세명 학생의 네 과목 성적', fontdict=font1)
plt.xlabel('이름')
plt.ylabel('성적')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
from random import *

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

def make_random_list(num) :
  result = []
  for i in range(num) :
    result.append(randrange(1, 7))
  return result

count = 10
y = make_random_list(count)
x = list(range(1, 11))

plt.title('주사위 10회 던지기', fontdict=font1)
plt.xlabel('던진 회수')
plt.ylabel('주사위 눈')
plt.bar(x, y)
plt.xticks(x)
plt.yticks([1, 2, 3, 4, 5, 6])

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
from random import *

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

def make_random_list(num) :
  result = []
  for i in range(num) :
    result.append(randrange(1, 7))
  return result

count = int(input("주사위를 던질 회수를 입력하시오: "))
y = make_random_list(count)
x = list(range(1, count+1))

plt.title('주사위 던질 횟수를 직접 선택하기: 주사위 '+ str(count)+'회 던지기', fontdict=font1)
plt.xlabel('던진 회수')
plt.ylabel('주사위 눈')
plt.bar(x, y)
plt.xticks(x)
plt.yticks([1, 2, 3, 4, 5, 6])

plt.show()
# Out:
# 주사위를 던질 회수를 입력하시오: 20

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
from random import *

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

def make_random_list(num) :
  result = []
  for i in range(num) :
    result.append(randrange(1, 7))
  return result

count = int(input("주사위를 던질 회수를 입력하시오: "))
y = make_random_list(count)
x = list(range(1, count+1))

plt.title('주사위 던질 횟수를 직접 선택하기: 주사위 '+ str(count)+'회 던지기', fontdict=font1)
plt.xlabel('던진 회수')
plt.ylabel('주사위 눈')
plt.bar(x, y)
plt.xticks(x)
plt.yticks([1, 2, 3, 4, 5, 6])

plt.show()
# Out:
# 주사위를 던질 회수를 입력하시오: 50

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

x = ['월', '화', '수', '목', '금', '토', '일']
y1 = [6.5, 5.7, 5.5, 6.7, 6.3, 7.5, 8.3]
y2 = [6.3, 7.7, 7.5, 7.7, 6.2, 7.3, 8.5]

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(9, 3), sharex=True, sharey=True)
ax = axs[0]
ax.scatter(x,y1)
ax.set_title('2018')

ax = axs[1]
ax.scatter(x,y2)
ax.set_title('2019')

fig.suptitle('연간 요일별 평균 수면시간')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

x = list(range(1, 11))
y = list(range(10, 101, 10))

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(9, 5), sharex=True, sharey=True)
ax = axs[0][0]
ax.plot(x,y)
ax.set_title('선 그래프 1')

ax = axs[0][1]
ax.plot(x,y, color='red', linestyle='--', marker='o')
ax.set_title('선 그래프 2')

ax = axs[1][0]
ax.bar(x,y)
ax.set_title('막대 그래프')

ax = axs[1][1]
ax.scatter(x,y)
ax.set_title('산포 그래프')

plt.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.2, hspace=0.3)
fig.suptitle('그래프 종류')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')

font1 = {'size':18, 'color':'green'}

name = input('이름을 입력하시오: ')
xdata = ['국어', '수학', '영어']
ydata = []
k_m = int(input('국어 성적을 입력하세요: '))
ydata.append(k_m)
s_m = int(input('수학 성적을 입력하세요: '))
ydata.append(s_m)
e_m = int(input('영어 성적을 입력하세요: '))
ydata.append(e_m)

plt.plot(xdata, ydata)

plt.ylim(0, 100)
plt.title('이름과 성적을 직접 입력하여 구하는 프로그램: ' + name + '의 국어 성적', fontdict=font1)
plt.xlabel('이름')
plt.ylabel('성적')

plt.show()
# Out:
# 이름을 입력하시오: 양예린
# 국어 성적을 입력하세요: 77
# 수학 성적을 입력하세요: 89
# 영어 성적을 입력하세요: 64

# %%
import matplotlib.pyplot as plt

xdata = list(range(100))
ydata =[]

for x in xdata:
  y = x**2
  ydata.append(y)

plt.plot(xdata, ydata, label = 'y=x**2')
plt.xlim(0, 105)
plt.ylim(0, 10005)
plt.xticks(list(range(0, 110, 5)))
plt.yticks(list(range(0, 10000, 1000)))

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

xdata = list(range(55))
ydata =[]

for x in xdata:
  y = x**3 + 3*x**2 + 3*x + 1
  ydata.append(y)

plt.plot(xdata, ydata, label = 'y=x**3+3*x**2+3*x+1')
plt.xlim(0, 55)
plt.ylim(0, 21000)
plt.xticks(list(range(0, 55, 5)))
plt.yticks(list(range(0, 200000, 10000)))

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from math import *

xdata = list(range(11))
ydata =[]

for x in xdata:
  y = factorial(x)
  ydata.append(y)

plt.plot(xdata, ydata, label = 'y = factorial(x)')
plt.xticks(list(range(0, 11, 1)))
plt.yticks(list(range(0, 1100000, 100000)))
plt.xlim(0, 11)
plt.ylim(0, 1100000)

plt.grid(True)
plt.show()

# %%
import folium

m = folium.Map()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

m = folium.Map(
    location=[37.566345, 126.977893],
    tiles='Stamen Terrain'
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

data1 = np.arange(1, 51)
plt.plot(data1)

data2 = np.arange(51, 101)
plt.plot(data2)

plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

oil = [30, 35, 40, 42, 45]
ton = ['5TON', '7TON', '10TON', '11TON', '15TON']
y_pos = np.arange(len(ton))

plt.bar(y_pos, oil)
plt.xticks(y_pos, ton)

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,10)
y = x*5

plt.plot(x,y,'ok')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,10)
y = x*5

plt.plot(x,y)
plt.annotate('annotate',xy=(2,10),xytext=(5,20),arrowprops={'color':'green'})
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]
plt.bar(x, values, width=1.0)
plt.xticks(x, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, align='edge', edgecolor='lightgray',
        linewidth=5, tick_label=years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, color=['r', 'g', 'b'])
plt.xticks(x, years)

plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['silver', 'gold', 'whitesmoke', 'lightgray']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import rc

f = open('cafe_2year.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

xdata = []
ydata = []
count = 1

for line in lines:
    if count%3 == 0 :
        xdata.append(line[0])
        ydata.append(line[1])

    count += 1
    
rc('font', family='Malgun Gothic')

font1 = {'size':18, 'color':'green'}

plt.bar(xdata, ydata)

plt.title('전국의 월별 까페수', fontdict=font1)
plt.xlabel('년월')
plt.ylabel('카페수')

plt.show()
        
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-dc1aae1c6c26> in <module>()
#       3 from matplotlib import rc
#       4
# ----> 5 f = open('cafe_2year.csv', 'r', encoding='utf-8')
#       6 lines = csv.reader(f)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cafe_2year.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

filename = '/content/drive/MyDrive/Colab Notebooks/중간과제/cafe_2year.csv'
data = pd.read_csv(filename)
data.head()
# Out:
#       기준월    카페수
# 0  201710  79296
# 1  201711  80738
# 2  201712  76923
# 3  201801  77942
# 4  201802  84967

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')
font1 = {'size':18, 'color':'green'}

f = open('/content/drive/MyDrive/Colab Notebooks/중간과제/cafe_2year.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

xdata = []
ydata = []
count = 1

for line in lines:
    if count%3 == 0 :
        xdata.append(line[0])
        ydata.append(line[1])

    count += 1

plt.bar(xdata, ydata)

plt.title('전국의 월별 까페수', fontdict=font1)
plt.xlabel('년월')
plt.ylabel('카페수')

plt.show()
        
f.close()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')
font1 = {'size':18, 'color':'green'}

f = open('/content/drive/MyDrive/Colab Notebooks/중간과제/doctor2.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

xdata = []
ydata = []

for line in lines:
    xdata.append(line[0])
    ydata.append(int(line[4]))

plt.scatter(xdata, ydata)

plt.title('서울 및 광역시 종합병원 전문의 수', fontdict=font1)
plt.xlabel('시')
plt.ylabel('의사 수')

plt.show()
        
f.close()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')
font1 = {'size':18, 'color':'green'}

f = open('/content/drive/MyDrive/Colab Notebooks/중간과제/doctor2.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

xdata = []
ydata1 = []
ydata2 = []
ydata3 = []
ydata4 = []

for line in lines:
    xdata.append(line[0])
    ydata1.append(int(line[1]))
    ydata2.append(int(line[2]))
    ydata3.append(int(line[3]))
    ydata4.append(int(line[4]))

plt.plot(xdata, ydata1, label='일반의', color='red', linestyle='-', marker='o')
plt.plot(xdata, ydata2, label='인턴', color='blue', linestyle='--', marker='x')
plt.plot(xdata, ydata3, label='레지던트', color='yellow', linestyle=':', marker='s')
plt.plot(xdata, ydata4, label='전문의', color='purple', linestyle='-.', marker='d')

plt.title('서울 및 광역시 종합병원 의사 수', fontdict=font1)
plt.legend(loc='best')
plt.xlabel('시')
plt.ylabel('의사 수')

plt.show()
        
f.close()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')
font1 = {'size':18, 'color':'green'}

f = open('/content/drive/MyDrive/Colab Notebooks/중간과제/doctor2.csv', 'r', encoding='utf-8')
lines = csv.reader(f)
header = next(lines)

kind = ['일반의', '인턴', '레지던트', '전문의']

numbers = []
seoul = next(lines)

total = 0
for i in range(4) :
    total += int(seoul[i+1])
    
for i in range(4) :
    persent = int(seoul[i+1])/total;
    numbers.append(persent)

plt.pie(numbers, explode=(0, 0.1, 0, 0), labels=kind, autopct='%.1f%%', shadow=True, startangle=90)
plt.title('서울 종합병원 의사 유형별 분포', fontdict=font1)
plt.show()
        
f.close()

# %%
import matplotlib.pyplot as plt

weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight)

plt.show()

# %%
import matplotlib.pyplot as plt

weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight, label='bins=10')
plt.hist(weight, bins=30, label='bins=30')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
          80, 59, 67, 81, 69, 73, 69, 74, 70, 65]

plt.hist(weight, cumulative=True, label='cumulative=True')
plt.hist(weight, cumulative=False, label='cumulative=False')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71,
        80, 59, 67, 81, 69, 73, 69, 74, 70, 65]
weight2 = [52, 67, 84, 66, 58, 78, 71, 57, 76, 62, 51, 79,
        69, 64, 76, 57, 63, 53, 79, 64, 50, 61]

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(9,5), sharex=True, sharey=True)

ax = axs[0][0]
ax.hist((weight, weight2), histtype='bar')
ax.set_title('histtype - bar')

ax = axs[0][1]
ax.hist((weight, weight2), histtype='barstacked')
ax.set_title('histtype - barstacked')

ax = axs[1][0]
ax.hist((weight, weight2), histtype='step')
ax.set_title('histtype - step')

ax = axs[1][1]
ax.hist((weight, weight2), histtype='stepfilled')
ax.set_title('histtype - stepfilled')
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')
font1 = {'size':18, 'color':'green'}

f = open('/content/drive/MyDrive/Colab Notebooks/중간과제/school_2019.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

schools = {}

for line in lines:
    if ('광주' in line[0]) and ('마재' in line[1]) :
        schools.update({'마재':[line[2], line[3], line[4]]})
    if ('울산' in line[0]) and ('약사' in line[1]) :
        schools.update({'약사':[line[2], line[3], line[4]]})
    if ('용인' in line[0]) and ('정평' in line[1]) :
        schools.update({'정평':[line[2], line[3], line[4]]})        
    if ('제주' in line[0]) and ('도평' in line[1]) :
        schools.update({'도평':[line[2], line[3], line[4]]})        

print(schools)

data = np.zeros((4,3), dtype='int32')

school = list(schools.values())

for i in range(len(schools)) :
    for j in range(3) :
        data[i][j] = school[i][j]

print(data)

data = np.insert(data, 2, 0, axis=1)
data = np.insert(data, 4, 0, axis=1)
print(data)

row = data.shape[0]
for i in range(row) :
    data[i][2] = round(data[i][1]/data[i][0])
    data[i][4] = round(data[i][1]/data[i][3])

print(data)

xdata = ['마재', '약사', '정평', '도평']

plt.plot(xdata, data[:, 1], label='학생수',  color='red', linestyle='--', marker='x')
plt.plot(xdata, data[:, 3], label='교사수', color='blue', linestyle=':', marker='d')
plt.title('마재/약사/정평/도평 초등학교 학생수와 교사수')
plt.legend(loc='best')
plt.show()

plt.plot(xdata, data[:, 2], label='학급당 학생수',  color='magenta', linestyle='-.', marker='o')
plt.plot(xdata, data[:, 4], label='교사 1인당 학생수', color='green', linestyle='--', marker='x')
plt.title('마재/약사/정평/도평 초등학교 학급당 학생수 및 교사 1인당 학생수')
plt.legend(loc='best')
plt.show()

f.close()
# Out:
# {'마재': ['24', '481', '28'], '약사': ['29', '685', '33'], '정평': ['36', '945', '43'], '도평': ['14', '300', '17']}
# [[ 24 481  28]
#  [ 29 685  33]
#  [ 36 945  43]
#  [ 14 300  17]]
# [[ 24 481   0  28   0]
#  [ 29 685   0  33   0]
#  [ 36 945   0  43   0]
#  [ 14 300   0  17   0]]
# [[ 24 481  20  28  17]
#  [ 29 685  24  33  21]
#  [ 36 945  26  43  22]
#  [ 14 300  21  17  18]]

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc

rc('font', family='NanumBarunGothic')
font1 = {'size':18, 'color':'green'}

f = open('/content/drive/MyDrive/Colab Notebooks/중간과제/high_school_2019.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

header = next(lines)

list_data = []
for line in lines :
    list_data.append(line[:])

length = len(list_data)

data = np.zeros((length, 6), dtype='int32')

for i in range(length) :
    for j in range(6) :
        data[i][j] = list_data[i][j+2]

data_sum = np.sum(data, axis=0)

print('1학년 총 학생수 :', data_sum[1])
print('2학년 총 학생수 :', data_sum[3])
print('3학년 총 학생수 :', data_sum[5])

xdata = ['1학년', '2학년', '3학년']

plt.bar(xdata, [data_sum[1], data_sum[3], data_sum[5]])
plt.title('전국 고등학교 학년별 총 학생수')
plt.show()

f.close()
# Out:
# 1학년 총 학생수 : 463400
# 2학년 총 학생수 : 444714
# 3학년 총 학생수 : 500698

# %%
import csv

f = open('/content/drive/MyDrive/Colab Notebooks/중간과제/population_age_2020.csv', 'r', encoding='utf-8')
lines = csv.reader(f)

next(lines)

list_data = []
for line in lines :
    list_data.append(line[:])

print(list_data)
f.close()
# Out:
# [['서울', '9736962', '658355', '813563', '1455903', '1505729', '1563968', '1539385', '1200518', '688818', '263939', '40404', '6380'], ['부산', '3410925', '241624', '281120', '434692', '431911', '518321', '580966', '511174', '285602', '109312', '14396', '1807'], ['대구', '2432883', '186623', '234528', '321487', '303397', '391997', '428622', '311274', '171217', '74227', '8817', '694'], ['인천', '2954955', '239941', '281097', '405835', '417708', '490716', '515758', '344843', '172269', '74306', '11574', '908'], ['광주', '1456121', '125396', '162728', '207554', '191432', '244903', '234048', '155056', '91020', '38050', '5529', '405'], ['대전', '1473125', '120476', '151861', '212143', '199106', '242381', '243526', '170291', '88289', '39190', '5523', '339'], ['울산', '1145710', '103399', '115623', '147745', '158271', '190698', '211255', '136520', '57438', '21610', '2991', '160'], ['세종', '343788', '47454', '40574', '36273', '61442', '65714', '42907', '27813', '13609', '6863', '1084', '55'], ['경기도', '132653
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(111, projection='3d')

import numpy as np
x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)
ax.plot(x, y, z)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(111, projection='3d')

import numpy as np
x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)
ax.scatter(x, y, z, color = 'r', alpha = 0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(111, projection='3d')

import numpy as np
x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)
ax.scatter(x, y, z, color = 'r', alpha = 0.5)
ax.scatter(x, z, y, color = 'g', alpha = 0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(111, projection='3d')

import numpy as np
x = np.arange(0, 10, 0.1)
y = np.sin(x)
x_m, y_m = np.meshgrid(x, y)
z = x_m + 5 * y_m
ax.plot_surface(x, y, z, cmap="brg_r")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = [0, 0, 1, 1]
y = [0, 1, 0, 1]
z = [-1, -1, -1, -1]

X = np.arange(-0.5, 1.5, 0.1)
Y = np.arange(-0.5, 1.5, 0.1)
X, Y = np.meshgrid(X, Y)
Z = (float(-5/7) * Y) + (float(-4/7) * X)

ax.plot(x, y, z, linestyle="none", marker="o", mfc="none", markeredgecolor="red")
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.4, cmap=cm.jet)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y) :
  r = 2*x**2 + y**2
  ans = r *np.exp(-r)
  return ans

xn = 9
x = np.linspace(-2, 2, xn)
y = np.linspace(-2, 2, xn)

temp = np.zeros((len(x), len(y)))
for i in range(xn) :
  for j in range(xn) :
    temp[j, i] = f(x[i], y[j])

plt.figure(figsize = (3.5, 3))
plt.gray()
plt.pcolor(temp)
plt.colorbar()
plt.show()

from mpl_toolkits.mplot3d import Axes3D
xx, yy = np.meshgrid(x, y)
plt.figure(figsize = (5, 3.5))
ax = plt.subplot(1, 1, 1, projection = '3d')

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y) :
  r = 2*x**2 + y**2
  ans = r *np.exp(-r)
  return ans

xn = 9
x = np.linspace(-2, 2, xn)
y = np.linspace(-2, 2, xn)

temp = np.zeros((len(x), len(y)))
for i in range(xn) :
  for j in range(xn) :
    temp[j, i] = f(x[i], y[j])

plt.figure(figsize = (3.5, 3))
plt.gray()
plt.pcolor(temp)
plt.colorbar()
plt.show()

from mpl_toolkits.mplot3d import Axes3D
xx, yy = np.meshgrid(x, y)
plt.figure(figsize = (5, 3.5))
ax = plt.subplot(1, 1, 1, projection = '3d')
ax.plot_surface(xx, yy, temp, rstride=1, cstride=1, alpha = 0.3, color = 'blue', edgecolor = 'black')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y) :
  r = 2*x**2 + y**2
  ans = r *np.exp(-r)
  return ans

xn = 9
x = np.linspace(-2, 2, xn)
y = np.linspace(-2, 2, xn)

temp = np.zeros((len(x), len(y)))
for i in range(xn) :
  for j in range(xn) :
    temp[j, i] = f(x[i], y[j])

plt.figure(figsize = (3.5, 3))
plt.gray()
plt.pcolor(temp)
plt.colorbar()
plt.show()

from mpl_toolkits.mplot3d import Axes3D
xx, yy = np.meshgrid(x, y)
plt.figure(figsize = (5, 3.5))
ax = plt.subplot(1, 1, 1, projection = '3d')
ax.plot_surface(xx, yy, temp, rstride=1, cstride=1, alpha = 0.3, color = 'blue', edgecolor = 'black')
ax.set_zticks((0,0.2))
ax.view_init(75, -95)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y) :
  r = 2*x**2 + y**2
  ans = r *np.exp(-r)
  return ans

xn = 50
x = np.linspace(-2, 2, xn)
y = np.linspace(-2, 2, xn)

temp = np.zeros((len(x), len(y)))
for i in range(xn) :
  for j in range(xn) :
    temp[j, i] = f(x[i], y[j])

plt.figure(figsize = (3.5, 3))
plt.gray()
plt.pcolor(temp)
plt.colorbar()
plt.show()

from mpl_toolkits.mplot3d import Axes3D
xx, yy = np.meshgrid(x, y)
plt.figure(figsize = (5, 3.5))
ax = plt.subplot(1, 1, 1, projection = '3d')
ax.plot_surface(xx, yy, temp, rstride=5, cstride=5, alpha = 0.3, color = 'blue', edgecolor = 'black')
ax.set_zticks((0,0.2))
ax.view_init(75, -95)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y) :
  r = 2*x**2 + y**2
  ans = r *np.exp(-r)
  return ans

xn = 50
x = np.linspace(-2, 2, xn)
y = np.linspace(-2, 2, xn)

temp = np.zeros((len(x), len(y)))
for i in range(xn) :
  for j in range(xn) :
    temp[j, i] = f(x[i], y[j])

xx, yy = np.meshgrid(x, y)

plt.figure(1, figsize = (4, 4))
cont = plt.contour(xx,yy,temp,5, colors = 'black')
cont.clabel(fmt = '%3.2f', fontsize = 8)
plt.xlabel('$x$', fontsize = 14)
plt.ylabel('$y$', fontsize = 14)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import population as pop

list_data = []

pop.get_list(list_data)
print(list_data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-b52911746fa7> in <module>()
# ----> 1 import population as pop
#       2
#       3 list_data = []
#       4
#       5 pop.get_list(list_data)
#
# ModuleNotFoundError: No module named 'population'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import pandas as pd

filename = '/content/drive/MyDrive/Colab Notebooks/중간과제/population_2020.csv'
data = pd.read_csv(filename)
data.head()
# Out:
#                   행정구역 2020년02월_총인구수 2020년02월_세대수  2020년02월_세대당 인구  \
# 0  서울특별시  (1100000000)     9,736,962    4,345,877             2.24
# 1  부산광역시  (2600000000)     3,410,925    1,502,333             2.27
# 2  대구광역시  (2700000000)     2,432,883    1,033,349             2.35
# 3  인천광역시  (2800000000)     2,954,955    1,242,107             2.38
# 4  광주광역시  (2900000000)     1,456,121      618,503             2.35
#
#   2020년02월_남자 인구수 2020년02월_여자 인구수  2020년02월_남여 비율
# 0       4,745,133       4,991,829            0.95
# 1       1,673,266       1,737,659            0.96
# 2       1,202,364       1,230,519            0.98
# 3       1,481,133       1,473,822            1.00
# 4         720,686         735,435            0.98

# %%
from google.colab import drive  
drive.mount('/content/drive')   

# %cd /content/drive/MyDrive/Colab Notebooks/중간과제/population.py/!ls

import sys

sys.path.insert(0, '/content/drive/MyDrive/Colab Notebooks/중간과제/population.py')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 20] Not a directory: '/content/drive/MyDrive/Colab Notebooks/중간과제/population.py/!ls'
# /content

# %%
dir(population)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-fac658734914> in <module>()
# ----> 1 dir(population)
#
# NameError: name 'population' is not defined

# %%
import population as pop

list_data = []

# CSV 파일을 읽어 들여 리스트 list_data에 저장
pop.get_list(list_data)     
print(list_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-81c3f74e3427> in <module>()
#       4
#       5 # CSV 파일을 읽어 들여 리스트 list_data에 저장
# ----> 6 pop.get_list(list_data)
#       7 print(list_data)
#
# AttributeError: module 'population' has no attribute 'get_list'

# %%
def get_list(list_data) :
    import csv
    f = open('/content/drive/MyDrive/Colab Notebooks/중간과제/population_2020.csv', 'r', encoding='utf-8')
    lines = csv.reader(f)

    header = next(lines)
               
    list_tmp = []
    for line in lines :                       
        list_tmp.append(line[:])
        
    for j in range(7) :                       
        tmp = []
        for i in range(len(list_tmp)) :     
            tmp.append(list_tmp[i][j])
        list_data.append(tmp)

def get_dict(list_data, keys, dict_data) :
    area = get_area(list_data[0])
    dict_data.update({keys[0]:area})

    for i in range(1, 7) :
        if i==3 or i==6 : 
            data = del_comma(list_data[i], 'float')
        else :
            data = del_comma(list_data[i], 'integer')
    
        dict_data.update({keys[i]:data})

def get_area(data) :            
    tmp = []
    for x in data :                      
        arr = x.split()             
        tmp.append(arr[0])
        
    return tmp

def del_comma(data, t) :
    tmp = []
    for x in data :
        string = ''
        arr = x.split(',')
        for i in range(len(arr)) :
            string += arr[i]
        
        if t == 'integer' :
            tmp.append(int(string))
        else :
            tmp.append(float(string))
        
    return tmp



import pandas as pd

list_data = []

get_list(list_data)         

dict_data = {}

keys = ['지역', '총인구수', '세대수', '세대당_인구', '남자_인구수', '여자_인구수', '남여_비율']

get_dict(list_data, keys, dict_data)              

frame = pd.DataFrame(dict_data)
print(frame)
# Out:
#          지역      총인구수      세대수  세대당_인구   남자_인구수   여자_인구수  남여_비율
# 0     서울특별시   9736962  4345877    2.24  4745133  4991829   0.95
# 1     부산광역시   3410925  1502333    2.27  1673266  1737659   0.96
# 2     대구광역시   2432883  1033349    2.35  1202364  1230519   0.98
# 3     인천광역시   2954955  1242107    2.38  1481133  1473822   1.00
# 4     광주광역시   1456121   618503    2.35   720686   735435   0.98
# 5     대전광역시   1473125   637726    2.31   735791   737334   1.00
# 6     울산광역시   1145710   469551    2.44   588626   557084   1.06
# 7   세종특별자치시    343788   136629    2.52   171403   172385   0.99
# 8       경기도  13265377  5497087    2.41  6672706  6592671   1.01
# 9       강원도   1539521   721003    2.14   774358   765163   1.01
# 10     충청북도   1598599   723931    2.21   809805   788794   1.03
# 11     충청남도   2120995   961890    2.21  1081153  1039842   1.04
# 12     전라북도   1815112   818452    2.22   902365   912747   0.99
# 13     전라남도   1861894   873871    2.13   934900   926994   1.01
# ...

# %%
def get_list(list_data) :
    import csv
    f = open('/content/drive/MyDrive/Colab Notebooks/중간과제/population_2020.csv', 'r', encoding='utf-8')
    lines = csv.reader(f)

    header = next(lines)
               
    list_tmp = []
    for line in lines :                       
        list_tmp.append(line[:])
        
    for j in range(7) :                       
        tmp = []
        for i in range(len(list_tmp)) :     
            tmp.append(list_tmp[i][j])
        list_data.append(tmp)

def get_dict(list_data, keys, dict_data) :
    area = get_area(list_data[0])
    dict_data.update({keys[0]:area})

    for i in range(1, 7) :
        if i==3 or i==6 : 
            data = del_comma(list_data[i], 'float')
        else :
            data = del_comma(list_data[i], 'integer')
    
        dict_data.update({keys[i]:data})

def get_area(data) :            
    tmp = []
    for x in data :                      
        arr = x.split()             
        tmp.append(arr[0])
        
    return tmp

def del_comma(data, t) :
    tmp = []
    for x in data :
        string = ''
        arr = x.split(',')
        for i in range(len(arr)) :
            string += arr[i]
        
        if t == 'integer' :
            tmp.append(int(string))
        else :
            tmp.append(float(string))
        
    return tmp


import pandas as pd
from matplotlib import rc

rc('font', family='NanumBarunGothic')
font1 = {'size':18, 'color':'green'}

list_data = []

get_list(list_data)

keys = ['지역', '총인구수', '세대수', '세대당_인구', '남자_인구수', '여자_인구수', '남여_비율']

dict_data = {}

get_dict(list_data, keys, dict_data)              

frame = pd.DataFrame(dict_data)
index = ['서울', '부산', '대구', '인천', '광주', '대전']

x1 = frame.iloc[:6, 1]
x1 = x1.values.tolist()

x2 = frame.iloc[:6, 2]
x2 = x2.values.tolist()

df = pd.DataFrame({'총인구수':x1, '총세대수':x2}, index=index)
ax = df.plot.bar(rot=0)
